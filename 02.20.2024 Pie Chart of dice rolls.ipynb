# %% [markdown]
# <a href="https://colab.research.google.com/github/Capta1nAlex/python/blob/main/02.20.2024%20Pie%20Chart%20of%20dice%20rolls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# An array of random numbers representing dice rolls
dice_rolls = np.random.randint(1, 7, size=300)

# Count the occurrences of each number
counts = np.bincount(dice_rolls)[1:]

# Labels for each section of the pie chart
labels = [str(i) for i in range(1, 7)]

# Create the pie chart
plt.pie(counts, labels=labels, autopct='%1.1f%%', startangle=90)

# Display the pie chart
plt.show()
